# %% [markdown]
# ## Import libraries

# %%
import faiss
import numpy as np
import pandas as pd
from read_s3 import read_s3_file
import time

# %% [markdown]
# ## Process data

# %%
BATCH_SIZE = 50000
BATCH_NUMBER = 10
BATCH_COUNT = 0
BATCH_COUNT_LIMIT = 10

df = pd.DataFrame(columns=["parent_asin", "embedding"])

# append all batches into one file
for i in range(BATCH_COUNT_LIMIT):
    key = f"data_vectors/file_0_7M_{BATCH_COUNT * BATCH_SIZE}_{(BATCH_COUNT + 1) * BATCH_SIZE - 1}"

    data = read_s3_file(key)

    if BATCH_COUNT == 0:
        df = data
    else:
        df = pd.concat([df, data], ignore_index=True)
    BATCH_COUNT += 1

## unpack embeddings into matrix

is_valid = df['embedding'].apply(lambda x: isinstance(x, np.ndarray) and x.shape == (384,))
df_clean = df[is_valid]

matrix = np.stack(df_clean['embedding'].values).astype('float32')

print(matrix.shape)
# (499971, 384)
# Out:
# (499971, 384)

# %% [markdown]
# ## Initialize Index using FAISS

# %%
index = faiss.IndexFlatL2(384)
index.add(matrix)

# %% [markdown]
# ## Query

# %%
from sentence_transformers import SentenceTransformer

# https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# prompt
query = "best eczema face wash for sensitive asian skin"

# convert query to vector
query_embedding = model.encode(query, convert_to_numpy=True).astype('float32')

# number of top results to retrieve
k = 100

## Search
D, I = index.search(query_embedding.reshape(1, -1), k)

# print("Distances:", D)
# print("Indices:", I)
# Retrieve the top-k results
top_k_results = df_clean.iloc[I[0]]

# top k parent_asins
top_k_parent_asins = top_k_results['parent_asin'].unique()

print("Top-k results:")
print(top_k_results[['parent_asin', 'embedding']])

## 0.3s
# Out:
# Top-k results:
#        parent_asin                                          embedding
# 311829  B09WYZJVFH  [0.0004865061, 0.059590034, 0.05439229, 0.0282...
# 179787  B000052YN9  [0.028374797, 0.13186209, 0.049382284, -0.0146...
# 62631   B00IFWC058  [-0.0064997077, 0.0636541, 0.05518529, -0.0043...
# 260439  B00SBSBI7M  [0.016015513, 0.077947654, 0.035339646, 0.0394...
# 89826   B0C5FJT32P  [-0.014239035, 0.17768838, 0.091014564, -0.012...
# ...            ...                                                ...
# 101747  B083M54MZL  [-0.08751378, -0.00069189805, 0.08085996, -0.0...
# 332462  B079SX37P4  [-0.050606657, 0.046125174, 0.07001063, 0.0504...
# 252408  B0C6BVZ7ZW  [-0.037568472, 0.040740255, 0.052189335, 0.065...
# 292970  B0C5S27LN6  [-0.057144377, 0.062027723, 0.09078525, 0.0511...
# 92      B000GEZTLK  [-0.044107404, 0.05610219, 0.064003825, -0.002...
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Validate

# %%
# function to return bayesian average rating
def bayesian_avg_rating(df):

    metadata_top_k = df.copy()

    metadata_top_k.columns = metadata_top_k.columns.str.lower()
    
    # https://www.algolia.com/doc/guides/managing-results/must-do/custom-ranking/how-to/bayesian-average/
    # C (confidence number): 25% percentile
    C = metadata_top_k['average_rating'].quantile(0.25)
    # m: smoothing factor -- median of rating_number
    m = metadata_top_k['rating_number'].median()

    metadata_top_k['bayes_average_rating'] = (
        (metadata_top_k['average_rating'] * metadata_top_k['rating_number'] + C * m) /
        (metadata_top_k['rating_number'] + m)
    )

    # sort by bayesian average rating and return top 5
    metadata_top_k_sorted = metadata_top_k.sort_values(by='bayes_average_rating', ascending=False)

    return metadata_top_k_sorted

# %% [markdown]
# ### Connect from S3 Parquet

# %%
#### Read parquet from S3 method
start_time = time.time()

# retrieve meta data for product names
metadata_key = 'meta_data.parquet'

metadata = read_s3_file(metadata_key)

# search relevant products
metadata_top_k = metadata[metadata['parent_asin'].isin(top_k_parent_asins)]

# calculate and sort by bayes avg rating
metadata_top_k_sorted = bayesian_avg_rating(metadata_top_k)

print(f"final time: {time.time() - start_time:.2f} seconds")
metadata_top_k_sorted.head(5)
# Out:
# final time: 12.88 seconds
#        main_category                                              title  \
# 179752    All Beauty  Aveeno Daily Moisturizing Lotion & Wash Regime...
# 465920    All Beauty  NOW Solutions, Grapeseed Oil, Skin Care for Se...
# 183642    All Beauty  Sky Organics Organic Lip Balms With Beeswax fo...
# 746593    All Beauty  Elizabeth Taylor Women's Perfume, Passion, Eau...
# 725700    All Beauty  Lubriderm Daily Moisture Hydrating Unscented B...
#
#         average_rating  rating_number  \
# 179752             4.7          44872
# 465920             4.7          21373
# 183642             4.6          14795
# 746593             4.6           5371
# 725700             4.7           1734
#
#                                                  features  \
# 179752  [2 item Aveeno Daily Moisturizing Lotion and B...
# 465920  [SENSITIVE SKIN CARE: 100% Pure Grapeseed Oil ...
# 183642  [WHY WE LOVE IT: Sky Organics Organic Lip Balm...
# 746593  [Passion by Elizabeth Taylor is as fiery and a...
# 725700  [3-fluid ounce tube of Lubriderm Daily Moistur...
#
#                                               description  price  \
# 179752  [Gently cleanse and nourish dry, sensitive ski...  19.57
# 465920  [100% Pure Grapeseed Oil is a light, odorless ...  12.45
# 183642                                                 []   6.88
# 746593  [Passion By Elizabeth Taylor For Women, Eau De...  21.33
# 725700  [Ideal for normal-to-dry skin types, Lubriderm...   None
#
#                                                    images  \
# 179752  {'hi_res': ['https://m.media-amazon.com/images...
# 465920  {'hi_res': ['https://m.media-amazon.com/images...
# 183642  {'hi_res': ['https://m.media-amazon.com/images...
# 746593  {'hi_res': ['https://m.media-amazon.com/images...
# 725700  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                                    videos             store  \
# 179752  {'title': ['Aveeno Daily Moisturizer, Body Lot...            Aveeno
# 465920  {'title': ['Want That Kardashian Skin Glow. Ha...               NOW
# 183642            {'title': [], 'url': [], 'user_id': []}      Sky Organics
# 746593  {'title': ['Women's Perfume by Elizabeth Taylo...  Elizabeth Taylor
# 725700  {'title': ['Style Code Live: Tika Sumpter', 'L...         Lubriderm
#
#                                                categories  \
# 179752  [Beauty & Personal Care, Skin Care, Body, Mois...
# 465920  [Beauty & Personal Care, Skin Care, Body, Mois...
# 183642  [Beauty & Personal Care, Skin Care, Lip Care, ...
# 746593  [Beauty & Personal Care, Fragrance, Women's, E...
# 725700  [Beauty & Personal Care, Skin Care, Body, Mois...
#
#                                                   details parent_asin  \
# 179752  {"Package Dimensions": "11.34 x 5.31 x 4.17 in...  B0C6BVZ7ZW
# 465920  {"Brand": "NOW", "Scent": "Grape Seed O", "Ite...  B09KX3VVBH
# 183642  {"Brand": "Sky Organics", "Item Form": "Stick"...  B0BR7SG5MH
# 746593  {"Brand": "Elizabeth Taylor", "Item Form": "Sp...  B0CFGDPNCH
# 725700  {"Brand": "Lubriderm", "Scent": "Fragrance Fre...  B005IHSTRQ
#
#        bought_together subtitle author  bayes_average_rating
# 179752            None     None   None              4.690466
# 465920            None     None   None              4.680328
# 183642            None     None   None              4.576658
# 746593            None     None   None              4.540571
# 725700            None     None   None              4.523185

# %% [markdown]
# ### Connect from Snowflake

# %%
import snowflake.connector as sfcon
from dotenv import load_dotenv
import os

load_dotenv()

snowflake_account  = os.getenv('SNOWFLAKE_ACCOUNT')
snowflake_user = os.getenv('SNOWFLAKE_USER')
snowflake_password = os.getenv('SNOWFLAKE_PASSWORD')
snowflake_db= os.getenv('SNOWFLAKE_DB')
snowflake_wh= os.getenv('SNOWFLAKE_WH')
snowflake_schema = os.getenv('SNOWFLAKE_SCHEMA')
snowflake_meta_table = os.getenv('SNOWFLAKE_META_TABLE')

# establish con
conn = sfcon.connect(
    user=snowflake_user,
    password=snowflake_password,
    account=snowflake_account,
    database=snowflake_db,
    warehouse=snowflake_wh,
    schema=snowflake_schema,
    meta_table=snowflake_meta_table
)

# create cursor
cursor = conn.cursor()

placeholders = ', '.join(['%s' for _ in top_k_parent_asins])

# query Snowflake
results = cursor.execute(
    f'''
    SELECT
        average_rating,
        ARRAY_TO_STRING(categories, ',') as categories_clean,
        ARRAY_TO_STRING(description, ',') as description_clean,
        REPLACE(details, '\\n', '') as details,
        ARRAY_TO_STRING(features, ',') as features_clean,
        images :: string as images,
        main_category,
        parent_asin,
        price,
        rating_number,
        store,
        title,
        videos :: string as videos    
    FROM META_DATA_TABLE
    WHERE parent_asin in ({placeholders})
    ''',
    top_k_parent_asins.tolist()
).fetchall()

# retrieve column names
results_column_name = cursor.execute(
    f'''
    SELECT COLUMN_NAME
    FROM INFORMATION_SCHEMA.COLUMNS
    WHERE TABLE_SCHEMA = '{snowflake_schema}'  
    AND TABLE_NAME = '{snowflake_meta_table}'
    ORDER BY ORDINAL_POSITION
    '''
).fetchall()

results_column_names = [col[0] for col in results_column_name]

# convert to df
results_df = pd.DataFrame(results, columns=results_column_names)

# sort by bayesian average rating
snowflake_top_k_sorted = bayesian_avg_rating(results_df)

# close cursor and connection
cursor.close()
conn.close()

# results_df
snowflake_top_k_sorted
# Out:
#     average_rating                                         categories  \
# 17             4.8  Beauty & Personal Care,Skin Care,Face,Creams &...
# 56             4.8  Beauty & Personal Care,Skin Care,Face,Cleanser...
# 50             4.8  Beauty & Personal Care,Skin Care,Body,Cleanser...
# 18             4.8  Beauty & Personal Care,Skin Care,Body,Cleanser...
# 27             4.8  Beauty & Personal Care,Skin Care,Body,Cleanser...
# ..             ...                                                ...
# 64             4.2  Beauty & Personal Care,Skin Care,Face,Cleanser...
# 6              4.2  Beauty & Personal Care,Skin Care,Face,Polishes...
# 66             4.3  Beauty & Personal Care,Skin Care,Body,Moisturi...
# 79             4.3  Beauty & Personal Care,Skin Care,Body,Cleanser...
# 47             4.2  Beauty & Personal Care,Skin Care,Body,Moisturi...
#
#                                           description  \
# 17  Developed with dermatologists, CeraVe Moisturi...
# 56  Cetaphil Gentle Cleansing Bar, Hypoallergenic,...
# 50  Dove Sensitive Skin Beauty Bar combines classi...
# 18  If you have sensitive skin, you know that it n...
# 27  Nourish your skin senses with Dove Hypoallerge...
# ..                                                ...
# 64  Eucerin Redness Relief Soothing Cleanser gentl...
# 6
# 66  E45 Cream is a trusted formula suitable for th...
# 79                                           TWO BARS
# 47  Why did we reformulate? Our previous formula h...
#
#                                               details  \
# 17  {"Brand": "CeraVe", "Scent": "Fragrance Free",...
# 56  {"Item Form": "Bar", "Skin Type": "Sensitive, ...
# 50  {"Item Form": "Bar", "Skin Type": "Sensitive",...
# 18  {"Item Form": "Lotion", "Skin Type": "Sensitiv...
# 27  {"Item Form": "Gel", "Skin Type": "Sensitive",...
# ..                                                ...
# 64  {"Item Form": "Gel", "Skin Type": "Sensitive",...
# 6   {"Brand": "Clean & Clear", "Item Form": "Gel",...
# 66  {"Brand": "E45", "Scent": "Eucalyptus", "Item ...
# 79  {"Item Form": "Bar", "Skin Type": "Dry", "Bran...
# 47  {"Brand": "Puracy", "Scent": "Unscented", "Ite...
#
#                                              features  \
# 17  [ HYALURONIC ACID MOISTURIZER ] With hyaluroni...
# 56  Free of any harsh detergents that may irritate...
# 50  GENTLE ON SENSITIVE SKIN: Nourish your skin wi...
# 18  Dove Body Wash for Sensitive Skin gently clean...
# 27  24HR RENEWING MICROMOISTURE: Dove Hypoallergen...
# ..                                                ...
# 64  ENRICHED: With Licochalcone, a skin soothing e...
# 6   5-ounce of Clean & Clear Oil-Free Deep Action ...
# 66  Effective, non-greasy emollient is quickly and...
# 79  For dry, irritated or damaged skin - won't clo...
# 47  UNSCENTED BODY LOTION THAT WORKS BETTER WITH E...
#
#                                                images           main_category  \
# 17  {"hi_res":["https://m.media-amazon.com/images/...              All Beauty
# 56  {"hi_res":["https://m.media-amazon.com/images/...              All Beauty
# 50  {"hi_res":["https://m.media-amazon.com/images/...              All Beauty
# 18  {"hi_res":["https://m.media-amazon.com/images/...              All Beauty
# 27  {"hi_res":["https://m.media-amazon.com/images/...              All Beauty
# ..                                                ...                     ...
# 64  {"hi_res":["https://m.media-amazon.com/images/...              All Beauty
# 6   {"hi_res":["https://m.media-amazon.com/images/...              All Beauty
# 66  {"hi_res":["https://m.media-amazon.com/images/...  Health & Personal Care
# 79  {"hi_res":[null],"large":["https://m.media-ama...              All Beauty
# 47  {"hi_res":["https://m.media-amazon.com/images/...              All Beauty
#
#    parent_asin  price  rating_number          store  \
# 17  B08KVK68F7  17.78         117967         CeraVe
# 56  B0B4H48J4J   5.49          16565       Cetaphil
# 50  B07X1VDZ73  15.74          14446           Dove
# 18  B08373D96S   None          11698           Dove
# 27  B0BY5NX1BK   None           5005           Dove
# ..         ...    ...            ...            ...
# 64  B006R6VJBK   None            292        Eucerin
# 6   B0056AY5GY   None            642  Clean & Clear
# 66  B004AV1J2S  32.02           3456            E45
# 79  B012YJZPN6  12.99           4194     SOAP WORKS
# 47  B082QN78GK   None           2270         Puracy
#
#                                                 title  \
# 17  CeraVe Moisturizing Cream | Body and Face Mois...
# 56  CETAPHIL Gentle Cleansing Bar, 4.5 oz , Nouris...
# 50  Dove Beauty Bar More Moisturizing Than Bar Soa...
# 18  Dove Hypoallergenic Body Wash To Moisturize Se...
# 27  Dove Body Wash With Pump Sensitive Skin 3 Coun...
# ..                                                ...
# 64  Eucerin Sensitive Skin Redness Relief Cleansin...
# 6   Clean & Clear Oil-Free Deep Action Exfoliating...
# 66  E45 Eucalyptus Scented Cream, 500g - Whole Bod...
# 79    Soap Works Emu Oil Soap Bar 2 BARS (110g) Brand
# 47  Puracy Unscented Lotion, Fragrance Free Lotion...
#
#                                                videos  bayes_average_rating
# 17  {"title":["Watch before you buy | Honest Revie...              4.794998
# 56  {"title":["Leaves Your Face Feeling Clean","Be...              4.766908
# 50  {"title":["Honest Review Dove Beauty Bar","In ...              4.762509
# 18  {"title":["Its Real Not Fake !!!","Feels amazi...              4.754700
# 27  {"title":["Dove Sensitive Skin- Watch before y...              4.708047
# ..                                                ...                   ...
# 64  {"title":["Eucerin Redness Relief Cleansing Ge...              4.367301
# 6                  {"title":[],"url":[],"user_id":[]}              4.339888
# 66                 {"title":[],"url":[],"user_id":[]}              4.330182
# 79  {"title":["Good for skin sensitive or itchy"],...              4.326266
# 47  {"title":["Watery lotion?!","Quick Review of A...              4.279384
#
# [89 rows x 14 columns]
